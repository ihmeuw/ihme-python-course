# %% [markdown]
# # Exercise 3
#
# Adapted from Software Carpentry's [Gapminder tutorial](http://swcarpentry.github.io/python-novice-gapminder/08-data-frames/)

# %% [markdown]
# ### Part 1

# %% [markdown]
# Load the Gapminder GDP data for Europe into a Pandas DataFrame
#
#     data/gapminder_gdp_europe.csv

# %%
import pandas as pd

# %%
df = pd.read_csv('data/gapminder_gdp_europe.csv')

# %%
df.head()
# Out:
#                   country  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# 0                 Albania     1601.056136     1942.284244     2312.888958
# 1                 Austria     6137.076492     8842.598030    10750.721110
# 2                 Belgium     8343.105127     9714.960623    10991.206760
# 3  Bosnia and Herzegovina      973.533195     1353.989176     1709.683679
# 4                Bulgaria     2444.286648     3008.670727     4254.337839
#
#    gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  \
# 0     2760.196931     3313.422188     3533.003910     3630.880722
# 1    12834.602400    16661.625600    19749.422300    21597.083620
# 2    13149.041190    16672.143560    19117.974480    20979.845890
# 3     2172.352423     2860.169750     3528.481305     4126.613157
# 4     5577.002800     6597.494398     7612.240438     8224.191647
#
#    gdpPercap_1987  gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  \
# ...

# %% [markdown]
# Set the `country` name as the index on this dataframe

# %%
df = df.set_index('country')
df.head()
# Out:
#                         gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Albania                    1601.056136     1942.284244     2312.888958
# Austria                    6137.076492     8842.598030    10750.721110
# Belgium                    8343.105127     9714.960623    10991.206760
# Bosnia and Herzegovina      973.533195     1353.989176     1709.683679
# Bulgaria                   2444.286648     3008.670727     4254.337839
#
#                         gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  \
# country
# Albania                    2760.196931     3313.422188     3533.003910
# Austria                   12834.602400    16661.625600    19749.422300
# Belgium                   13149.041190    16672.143560    19117.974480
# Bosnia and Herzegovina     2172.352423     2860.169750     3528.481305
# Bulgaria                   5577.002800     6597.494398     7612.240438
#
#                         gdpPercap_1982  gdpPercap_1987  gdpPercap_1992  \
# country
# ...

# %% [markdown]
# Instead, add the `country` index during the call to `.read_csv()`
#
# _Hint_: it's one of the first 10 arguments listed by `pd.read_csv?`

# %%
df = pd.read_csv('data/gapminder_gdp_europe.csv', index_col='country')
df.head()
# Out:
#                         gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Albania                    1601.056136     1942.284244     2312.888958
# Austria                    6137.076492     8842.598030    10750.721110
# Belgium                    8343.105127     9714.960623    10991.206760
# Bosnia and Herzegovina      973.533195     1353.989176     1709.683679
# Bulgaria                   2444.286648     3008.670727     4254.337839
#
#                         gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  \
# country
# Albania                    2760.196931     3313.422188     3533.003910
# Austria                   12834.602400    16661.625600    19749.422300
# Belgium                   13149.041190    16672.143560    19117.974480
# Bosnia and Herzegovina     2172.352423     2860.169750     3528.481305
# Bulgaria                   5577.002800     6597.494398     7612.240438
#
#                         gdpPercap_1982  gdpPercap_1987  gdpPercap_1992  \
# country
# ...

# %% [markdown]
# What was the GDP of Serbia in 2007?

# %%
df.loc['Serbia', 'gdpPercap_2007']
# Out:
# 9786.5347139999994

# %% [markdown]
# ### Part 2

# %% [markdown]
# What're the differences between the two statements below?

# %%
df.iloc[0:2, 0:2]
# Out:
#          gdpPercap_1952  gdpPercap_1957
# country
# Albania     1601.056136     1942.284244
# Austria     6137.076492     8842.598030

# %%
df.loc['Albania':'Belgium', 'gdpPercap_1952':'gdpPercap_1962']
# Out:
#          gdpPercap_1952  gdpPercap_1957  gdpPercap_1962
# country
# Albania     1601.056136     1942.284244     2312.888958
# Austria     6137.076492     8842.598030    10750.721110
# Belgium     8343.105127     9714.960623    10991.206760

# %% [markdown]
# How would you explain the differences between integer and labeled slicing on DataFrames?

# %% [markdown]
# _Integer slicing utilizes `iloc`, and operates on the interval [start, stop)_
#
# _Whereas labeled utilizes `loc`, and operates on the interval [start, stop]_

# %% [markdown]
# ### Part 3

# %% [markdown]
# Add comments to the steps below, describing what each does

# %%
# first, we read in the data for all countries, setting an index on country name 
first = pd.read_csv('data/gapminder_all.csv', index_col='country')
# .head() is used to show the first 5 rows of the loaded dataframe
first.head()
# Out:
#              continent  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Algeria         Africa     2449.008185     3013.976023     2550.816880
# Angola          Africa     3520.610273     3827.940465     4269.276742
# Benin           Africa     1062.752200      959.601080      949.499064
# Botswana        Africa      851.241141      918.232535      983.653976
# Burkina Faso    Africa      543.255241      617.183465      722.512021
#
#               gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  \
# country
# Algeria          3246.991771     4182.663766     4910.416756     5745.160213
# Angola           5522.776375     5473.288005     3008.647355     2756.953672
# Benin            1035.831411     1085.796879     1029.161251     1277.897616
# Botswana         1214.709294     2263.611114     3214.857818     4551.142150
# Burkina Faso      794.826560      854.735976      743.387037      807.198586
#
# ...

# %%
# second, the data is subset such that only countries in the Americas are left
second = first.loc[first['continent'] == 'Americas']
second.head()
# Out:
#           continent  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Argentina  Americas     5911.315053     6856.856212     7133.166023
# Bolivia    Americas     2677.326347     2127.686326     2180.972546
# Brazil     Americas     2108.944355     2487.365989     3336.585802
# Canada     Americas    11367.161120    12489.950060    13462.485550
# Chile      Americas     3939.978789     4315.622723     4519.094331
#
#            gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  \
# country
# Argentina     8052.953021     9443.038526    10079.026740     8997.897412
# Bolivia       2586.886053     2980.331339     3548.097832     3156.510452
# Brazil        3429.864357     4985.711467     6660.118654     7030.835878
# Canada       16076.588030    18970.570860    22090.883060    22898.792140
# Chile         5106.654313     5494.024437     4756.763836     5095.665738
#
#            gdpPercap_1987  gdpPercap_1992    ...        pop_1962    pop_1967  \
# ...

# %%
# third, Puerto Rico is dropped from the remaining data
third = second.drop('Puerto Rico')
print(second.shape, third.shape)
# Out:
# (25, 37) (24, 37)

# %%
# fourth, the continent variable is dropped because it is no longer needed
fourth = third.drop('continent', axis=1)
fourth.head()
# Out:
#            gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# country
# Argentina     5911.315053     6856.856212     7133.166023     8052.953021
# Bolivia       2677.326347     2127.686326     2180.972546     2586.886053
# Brazil        2108.944355     2487.365989     3336.585802     3429.864357
# Canada       11367.161120    12489.950060    13462.485550    16076.588030
# Chile         3939.978789     4315.622723     4519.094331     5106.654313
#
#            gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# country
# Argentina     9443.038526    10079.026740     8997.897412     9139.671389
# Bolivia       2980.331339     3548.097832     3156.510452     2753.691490
# Brazil        4985.711467     6660.118654     7030.835878     7807.095818
# Canada       18970.570860    22090.883060    22898.792140    26626.515030
# Chile         5494.024437     4756.763836     5095.665738     5547.063754
#
# ...

# %%
# finally, the results are saved to a new csv file
fourth.to_csv('data/results.csv')

# %% [markdown]
# ### Part 4
#
# Go back to the European Gapminder data and answer the following questions:

# %%
df = pd.read_csv('data/gapminder_gdp_europe.csv', index_col='country')
df.head()
# Out:
#                         gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Albania                    1601.056136     1942.284244     2312.888958
# Austria                    6137.076492     8842.598030    10750.721110
# Belgium                    8343.105127     9714.960623    10991.206760
# Bosnia and Herzegovina      973.533195     1353.989176     1709.683679
# Bulgaria                   2444.286648     3008.670727     4254.337839
#
#                         gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  \
# country
# Albania                    2760.196931     3313.422188     3533.003910
# Austria                   12834.602400    16661.625600    19749.422300
# Belgium                   13149.041190    16672.143560    19117.974480
# Bosnia and Herzegovina     2172.352423     2860.169750     3528.481305
# Bulgaria                   5577.002800     6597.494398     7612.240438
#
#                         gdpPercap_1982  gdpPercap_1987  gdpPercap_1992  \
# country
# ...

# %% [markdown]
# **1**: List the GDP for each country in 1982

# %%
df['gdpPercap_1982']
# Out:
# country
# Albania                    3630.880722
# Austria                   21597.083620
# Belgium                   20979.845890
# Bosnia and Herzegovina     4126.613157
# Bulgaria                   8224.191647
# Croatia                   13221.821840
# Czech Republic            15377.228550
# Denmark                   21688.040480
# Finland                   18533.157610
# France                    20293.897460
# Germany                   22031.532740
# Greece                    15268.420890
# Hungary                   12545.990660
# Iceland                   23269.607500
# Ireland                   12618.321410
# Italy                     16537.483500
# Montenegro                11222.587620
# Netherlands               21399.460460
# Norway                    26298.635310
# Poland                     8451.531004
# Portugal                  11753.842910
# Romania                    9605.314053
# Serbia                    15181.092700
# Slovak Republic           11348.545850
# ...

# %% [markdown]
# **2**: What was the GDP per capita in Denmark for each year?

# %%
df.loc['Denmark']
# Out:
# gdpPercap_1952     9692.385245
# gdpPercap_1957    11099.659350
# gdpPercap_1962    13583.313510
# gdpPercap_1967    15937.211230
# gdpPercap_1972    18866.207210
# gdpPercap_1977    20422.901500
# gdpPercap_1982    21688.040480
# gdpPercap_1987    25116.175810
# gdpPercap_1992    26406.739850
# gdpPercap_1997    29804.345670
# gdpPercap_2002    32166.500060
# gdpPercap_2007    35278.418740
# Name: Denmark, dtype: float64

# %% [markdown]
# **4**: What was the GDP for the United Kingdom in each year _beginning in 1992_?

# %%
df.loc['United Kingdom', 'gdpPercap_1992':]
# Out:
# gdpPercap_1992    22705.09254
# gdpPercap_1997    26074.53136
# gdpPercap_2002    29478.99919
# gdpPercap_2007    33203.26128
# Name: United Kingdom, dtype: float64

# %% [markdown]
# **5**: Calculate the ratio of each country's GDP per capita in 2007 to GDP per capita in 1952

# %%
ratio = df.gdpPercap_2007 / df.gdpPercap_1952
ratio
# Out:
# country
# Albania                   3.708196
# Austria                   5.886596
# Belgium                   4.038377
# Bosnia and Herzegovina    7.648736
# Bulgaria                  4.369697
# Croatia                   4.686795
# Czech Republic            3.320658
# Denmark                   3.639808
# Finland                   5.168805
# France                    4.334402
# Germany                   4.503060
# Greece                    7.799725
# Hungary                   3.421364
# Iceland                   4.978308
# Ireland                   7.806873
# Italy                     5.793425
# Montenegro                3.495221
# Netherlands               4.115376
# Norway                    4.889067
# Poland                    3.819475
# Portugal                  6.684325
# Romania                   3.437140
# Serbia                    2.732555
# Slovak Republic           3.680703
# Slovenia                  6.113405
# Spain                     7.517163
# ...

# %% [markdown]
# **6**: Which country had the largest relative GDP growth from 1952 to 2007?

# %%
ratio.sort_values(ascending=False).head(1)
# Out:
# country
# Ireland    7.806873
# dtype: float64

# %% [markdown]
# **Bonus**: Can you think of another way to calculate #6?

# %%
ratio.loc[ratio == ratio.max()]
# Out:
# country
# Ireland    7.806873
# dtype: float64

# %% [markdown]
# ### Bonus Exercise
#
# Take a look at `data/gapminder_all.csv` again - can you figure out the median GDP per capita in 2007 within each continent?

# %%
df = pd.read_csv('data/gapminder_all.csv', index_col='continent')
df.head()
# Out:
#                 country  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# continent
# Africa          Algeria     2449.008185     3013.976023     2550.816880
# Africa           Angola     3520.610273     3827.940465     4269.276742
# Africa            Benin     1062.752200      959.601080      949.499064
# Africa         Botswana      851.241141      918.232535      983.653976
# Africa     Burkina Faso      543.255241      617.183465      722.512021
#
#            gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  \
# continent
# Africa        3246.991771     4182.663766     4910.416756     5745.160213
# Africa        5522.776375     5473.288005     3008.647355     2756.953672
# Africa        1035.831411     1085.796879     1029.161251     1277.897616
# Africa        1214.709294     2263.611114     3214.857818     4551.142150
# Africa         794.826560      854.735976      743.387037      807.198586
#
# ...

# %%
continental_gdp = df.gdpPercap_2007.median(level=0)
continental_gdp
# Out:
# continent
# Africa       1452.267078
# Americas     8948.102923
# Asia         4471.061906
# Europe      28054.065790
# Oceania     29810.188275
# Name: gdpPercap_2007, dtype: float64
